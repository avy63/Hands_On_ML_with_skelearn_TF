# %%
from matplotlib.image import imread
from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt 
import numpy as np
image=imread(os.path.join("images","ladybug.jpg"))
print(image.shape)
print(image[1][1][1])
# Out:
# (431, 600, 3)
# 254

# %%
imshow(image)

# %%
X=image.reshape((-1,3))
X.shape
print(X[2][2])
# Out:
# 254

# %%
from sklearn.cluster import KMeans
kmeans=KMeans(n_clusters=5).fit(X)
segmeted_img=kmeans.cluster_centers_[kmeans.labels_]
segmeted_img=segmeted_img.astype(int)
segmeted_img=segmeted_img.reshape((image.shape))
segmeted_img.shape
print(segmeted_img[1][1][1])
# Out:
# 254

# %%
imshow(segmeted_img)
